# %% [markdown]
# <a href="https://colab.research.google.com/github/reyonecy/Potato_Disease_Classification/blob/main/Training%20Using%20Google%20Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32

# %%
dataset_path = "/content/drive/MyDrive/Potato_Dataset"
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    shuffle = True,
    image_size = (IMAGE_SIZE * IMAGE_SIZE),
    batch_size = BATCH_SIZE
)

# %%
# Looking the different classes of data
class_names = dataset.class_names
class_names

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
